# %%
text = 'I am a dog'
tokens = text.encode("utf-8")
tokens = list(map(int, tokens))
tokens
# Out:
# [73, 32, 97, 109, 32, 97, 32, 100, 111, 103]

# %%
import torch
torch.tril(torch.ones((3,3), dtype=bool))
# Out:
# tensor([[ True, False, False],
#         [ True,  True, False],
#         [ True,  True,  True]])

# %%
token_ids = [73, 32, 97, 109, 32, 97, 32, 100, 111, 103]
text = bytes(token_ids)
text = text.decode("utf-8")
text
# Out:
# 'I am a dog'
